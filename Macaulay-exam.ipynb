# %%
import numpy as np
from sympy import *
init_printing(use_unicode=True)

# %%
#Exercise  1 Basic
#1.1 find the solution of the following equation using gsympy

z, i, x = symbols('z, i, x')

solve((z**2+6*z+(1-2*I)), z)
# Out:
# ⎡       _________         _________⎤
# ⎣-3 - ╲╱ 8 + 2⋅ⅈ , -3 + ╲╱ 8 + 2⋅ⅈ ⎦

# %%
solve((4*z**2+24*z+37), z)
# Out:
# ⎡     ⅈ       ⅈ⎤
# ⎢-3 - ─, -3 + ─⎥
# ⎣     2       2⎦

# %%
X=solve((2*sin(5*x/2)-1), x)
Y=solve((2*sin(5*x/2)-1), sin(5*x/2))
print (X, Y)
# Out:
# ([pi/15, pi/3], [1/2])

# %%
solve(((3*x**2+1)-(x**2+1)**3), x)
# Out:
# [0, -√3⋅ⅈ, √3⋅ⅈ]

# %%
J=solve((4*cot(x)*cos(x)**2-cot(x)), x)
K=solve((4*cot(x)*cos(x)**2-cot(x)), cos(x))
print (J, K)
# Out:
# ([-2*pi/3, -pi/3, pi/3, 2*pi/3], [-1/2, 1/2])

# %%
# Exercise 1 Basic
# 1.2 Display the first and second derivatives of the following functions

# %%
d1=diff((2*sin(2*x)), x)
d2=diff(diff(d1), x)
print d1
print d2
# Out:
# 4*cos(2*x)
# -16*cos(2*x)

# %%
dx1=diff(cos(x)/(cos(x)+1), x)
dx2=diff((diff(dx1)), x)
print(dx1)
print(dx2)
# Out:
# -sin(x)/(cos(x) + 1) + sin(x)*cos(x)/(cos(x) + 1)**2
# sin(x)/(cos(x) + 1) - 7*sin(x)*cos(x)/(cos(x) + 1)**2 - 6*sin(x)**3/(cos(x) + 1)**3 + 6*sin(x)*cos(x)**2/(cos(x) + 1)**3 + 6*sin(x)**3*cos(x)/(cos(x) + 1)**4

# %%
df1=diff((x**2+1/x(x-1)**2), x)
df2=diff(diff(df1), x)
print(df1)
print(df2)
# Out:
# 2*x - 2*Subs(Derivative(x(_xi_1), _xi_1), (_xi_1,), (x - 1,))/x(x - 1)**3
# -2*Subs(Derivative(x(_xi_1), _xi_1, _xi_1, _xi_1), (_xi_1,), (x - 1,))/x(x - 1)**3 + 18*Subs(Derivative(x(_xi_1), _xi_1), (_xi_1,), (x - 1,))*Subs(Derivative(x(_xi_1), _xi_1, _xi_1), (_xi_1,), (x - 1,))/x(x - 1)**4 - 24*Subs(Derivative(x(_xi_1), _xi_1), (_xi_1,), (x - 1,))**3/x(x - 1)**5

# %%
# Exercise 1 Basic
# 1.3 integrate the first derivative of the above equation

# %%
integrate(d1, x)
# Out:
# 2⋅sin(2⋅x)

# %%
integrate(dx1, x)
# Out:
#                   log(cos(x) + 1)⋅cos(x)   log(cos(x) + 1)       1
# log(cos(x) + 1) - ────────────────────── - ─────────────── - ──────────
#                         cos(x) + 1            cos(x) + 1     cos(x) + 1

# %%
integrate(df1, x)
# Out:
#  2       1
# x  + ─────────
#       2
#      x (x - 1)

# %%
# Exercise 1 Basic
# using symPy plot sin (n*x)

# %%
x = symbols('x')
p1=(sin(1*x))
p2=(sin(2*x))
p3=(sin(3*x))
pl=plot(p1, p2, p3, (x, 0, 5))
pl[0].line_color = 'r'
pl[1].line_color = 'k'
pl[2].line_color = 'g'
pl.show()

# %%
# Exercise 2
import sympy as sym

# %%
V, g, y, Q, A, E, b= symbols('V, g, y, Q, A, E, b')

V=Q/A
E=((Q/(y/b))**2/2*g)+y

# %%
s1=E.subs(x, Q=30, g=9.81, b=10, y=2.4)
s1

# %%
# Exercise 3

# %%
A = np.array([[2, 3, 2, 1], [-1, 1, -1, 0], [0, 3, 0, 2], [0, 2, 2, 1]])
B = np.array([25, 7, 17, 20])
A, B
# Out:
# (array([[ 2,  3,  2,  1],
#         [-1,  1, -1,  0],
#         [ 0,  3,  0,  2],
#         [ 0,  2,  2,  1]]), array([25,  7, 17, 20]))
