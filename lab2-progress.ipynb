# %%
from sympy import *
x,y = symbols('x,y')
f = Function('f')(x**3+2*x-1)

# %%
diff(f.diff())
# Out:
# 6*x*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,)) + (3*x**2 + 2)**2*Subs(Derivative(f(_xi_1), _xi_1, _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
diff(x)
# Out:
# 1

# %%
f = x**3 + 2*x -1 
diff(f,x)
# Out:
# 3*x**2 + 2

# %%
diff(diff(f, x))
# Out:
# 6*x

# %%
integrate(diff(f,x))
# Out:
# x**3 + 2*x

# %%
diff(f,x,2)
# Out:
# 6*x

# %%
def f(x):
     return x**3 + 2*x -1
f(x)
print('first derivative: ' , diff(f(x), x))
print('second derivative: ', diff(diff(f(x), x)))
# Out:
# first derivative:  3*x**2 + 2
# second derivative:  6*x

# %%
f = atan(x)

# %%
diff (f,x)
# Out:
# 1/(x**2 + 1)

# %%
integrate(diff(f,x))
# Out:
# atan(x)

# %%
f = exp(x*2)
d = integrate(f ,x)
d
# Out:
# exp(2*x)/2

# %%
u = symbols('u')
plot(sin(u), (u, 0, pi/2))

# %%
plot(cos(u), (u, 0, pi/2))

# %%
plot(2*cos(x)-2+3*sin(2*x), (x, -pi, pi));

# %%
plot(x**2, x**3, x**4-x+1,(x,-10,10))

# %%
p1 = plot(x**2, (x, -10, 10))
p2 = plot(x**3, (x, -10, 10))

# %%
print(p1)
# Out:
# Plot object containing:
# [0]: cartesian line: x**2 for x over (-10.0, 10.0)

# %%
p1.extend(p2)

# %%
p1.show()

# %%
plot(x**2, x**3, (x, -5, 5))

# %%
c1 = 2*cos(x)-2+3*sin(2*x)
p1 = plot(cos(x), c1,(x, -pi, pi), legend=True, show=False)
p1[0].line_color= 'r'
p1[1].line_color = 'b'
p1.show()

# %%
l = [cos(n*x) for n in range(1, 4)]
p3 = plot(*l, (x, 0, 2*pi), show=False, title = '$\cos(nx)$ for n $\in$ [1, 3]', 
          legend=['cos(x)', 'cos(2x)', 'cos(3x)'])
p3[0].line_color = 'r'
p3[1].line_color = 'b'
p3[2].line_color = 'k'

p3.show()

# %%
plotting.plot_parametric((cos(u), sin(u)), (u, -pi, pi))

# %%
plotting.plot3d_parametric_line(cos(u), sin(u), u, (u, -5, 5))

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
 p6 = plot_implicit(y > sqrt(x))

# %%
plotting.plot_paramatric((cos(u), sin(u)), (u, cos(u) )
# Out:
#   File "<ipython-input-2-cb0446e1589d>", line 1
#     plotting.plot_paramatric((cos(u), sin(u)), (u, cos(u) )
#                                                            ^
# SyntaxError: unexpected EOF while parsing
